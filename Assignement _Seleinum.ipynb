# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
import time

# %%
driver1=webdriver.Chrome()

# %%
#Open the Naukaripage on automated chrome browser
driver1.get("https://www.naukri.com/")

# %%
job=driver1.find_element(By.CLASS_NAME,"suggestor-input")
job.send_keys("Data Scientist")

# %%
search=driver1.find_element(By.CLASS_NAME,"qsbSubmit")
search.click()

# %%
 # Apply location filter (Delhi/NCR) and salary filter (3-6 Lakhs)
loc = driver1.find_element(By.XPATH, '//label[@for="chk-Delhi / NCR-cityTypeGid-"]')
loc.click()

# %%
salary = driver1.find_element(By.XPATH, '//label[@for="chk-3-6 Lakhs-ctcFilter-"]')
salary.click()

# %%
# Find job title elements
title_tags1 = driver1.find_elements(By.XPATH, '//div[@class="cust-job-tuple layout-wrapper lay-2 sjw__tuple "]/div/a')

# Initialize an empty list to store job titles
job_titles1 = []

# Iterate over the title tags and collect job titles
for i, tag in enumerate(title_tags1):
    if i < 10:  # Limit to first 10 job titles
        job_title1 = tag.text
        job_titles1.append(job_title1)
    else:
        break  # Exit the loop once we have collected 10 job titles

# %%
# Find job loc elements
loc_tags1 = driver1.find_elements(By.XPATH, '//span[@class="locWdth"]')

job_loc1 = []

for i, tag in enumerate(loc_tags1):
    if i < 10:  # Limit to first 10 job titles
        loc1 = tag.text
        job_loc1.append(loc1)
    else:
        break

# %%
# Find exp elements
exp_tags1 = driver1.find_elements(By.XPATH, '//span[@class="expwdth"]')

job_exp1 = []

for i, tag in enumerate(exp_tags1):
    if i < 10:  # Limit to first 10 job titles
        exp1 = tag.text
        job_exp1.append(exp1)
    else:
        break

# %%
print(len(job_titles1),len(job_loc1),len(job_exp1))

# %%
import pandas as pd
df=pd.DataFrame({"Title":job_titles1,"Location":job_loc1,"Expereince":job_exp1,})
df
# Out:
#                     Title                                           Location  \
# 0          Data Scientist                       Delhi / NCR, Pune, Bengaluru
# 1          Data Scientist  Kolkata, Mumbai, New Delhi, Hyderabad, Pune, C...
# 2      Data Scientist III                                           Gurugram
# 3          Data Scientist  Kolkata, Mumbai, New Delhi, Hyderabad, Pune, C...
# 4          Data Scientist  Kolkata, Mumbai, New Delhi, Hyderabad, Pune, C...
# 5   Python Data Scientist  Kolkata, Mumbai, New Delhi, Hyderabad, Pune, C...
# 6          Data Scientist  Kolkata, Mumbai, New Delhi, Hyderabad, Pune, C...
# 7          Data Scientist                                          New Delhi
# 8          Data scientist                                           Gurugram
# 9  Data Scientist (Telco)                                Gurugram, Bengaluru
#
#   Expereince
# 0   6-11 Yrs
# 1    2-5 Yrs
# 2    2-6 Yrs
# 3    2-6 Yrs
# 4    3-7 Yrs
# 5    2-7 Yrs
# 6    3-7 Yrs
# ...

# %% [raw]
# Q2: Write a python program to scrape data for “Data Scientist” Job position in “Bangalore” location. You have to scrape the
# job-title, job-location, company_name, experience_required. You have to scrape first 10 jobs data.
# This task will be done in following steps:
# 1. First get the webpage https://www.shine.com/
# 2. Enter “Data Analyst” in “Job title, Skills” field and enter “Bangalore” in “enter the location” field.
# 3. Then click the searchbutton.
# 4. Then scrape the data for the first 10 jobs results you get.
# 5. Finally create a dataframe of the scraped data.

# %%
driver=webdriver.Chrome()

# %%
driver.get("https://www.shine.com/")

# %%
# Find the job title input field
job_title_field = driver.find_element(By.ID, "id_q")

# Use send_keys to type into the input field
job_title_field.send_keys("Data Analyst")

# %%
location_field = driver.find_element(By.ID, "id_loc")
location_field.send_keys("Bangalore")

# %%
Exp = driver.find_element(By.ID, "id_exp")
Exp.send_keys("4")

# %%
search=driver.find_element(By.CLASS_NAME,'searchForm_btnWrap__Cb75F')
search.click()

# %%
# Find job title elements
title_tags = driver.find_elements(By.XPATH, '//strong[@class="jobCard_pReplaceH2__xWmHg"]')

# Initialize an empty list to store job titles
job_titles = []

# Iterate over the title tags and collect job titles
for i, tag in enumerate(title_tags):
    if i < 10:  # Limit to first 10 job titles
        job_title = tag.text
        job_titles.append(job_title)
    else:
        break  # Exit the loop once we have collected 10 job titles

# %%
# Find job loc elements
loc_tags = driver.find_elements(By.XPATH, '//div[@class="jobCard_jobCard_lists_item__YxRkV jobCard_locationIcon__zrWt2"]')

# Initialize an empty list to store job titles
job_loc = []


for i, tag in enumerate(loc_tags):
    if i < 10:  # Limit to first 10 job titles
        loc = tag.text
        job_loc.append(loc)
    else:
        break

# %%
# Find exp elements
exp_tags = driver.find_elements(By.XPATH, '//div[@class=" jobCard_jobCard_lists_item__YxRkV jobCard_jobIcon__3FB1t"]')


job_exp = []

# Iterate over the title tags and collect job titles
for i, tag in enumerate(exp_tags):
    if i < 10:  # Limit to first 10 job titles
        exp = tag.text
        job_exp.append(exp)
    else:
        break

# %%
print(len(job_titles),len(job_loc),len(job_exp))
# Out:
# 10 10 10

# %%
import pandas as pd
df=pd.DataFrame({"Title":job_titles,"Location":job_loc,"Expereince":job_exp})
df
# Out:
#                                                Title       Location  \
# 0                                       Data Analyst  Bangalore\n+4
# 1                                    Hr Data Analyst      Bangalore
# 2  Data Analyst , Senior Data Analyst , Data Anal...  Bangalore\n+8
# 3                                       Data Analyst      Bangalore
# 4                                       Data Analyst      Bangalore
# 5                                       Data Analyst      Bangalore
# 6                              Clinical Data Analyst  Bangalore\n+6
# 7                              Clinical Data Analyst  Bangalore\n+6
# 8                                       Data Analyst      Bangalore
# 9                              Clinical Data Analyst  Bangalore\n+6
#
#     Expereince
# 0   0 to 4 Yrs
# 1   4 to 8 Yrs
# 2   0 to 4 Yrs
# 3   3 to 8 Yrs
# 4   2 to 7 Yrs
# 5   2 to 7 Yrs
# 6    0 to 1 Yr
# 7    0 to 1 Yr
# 8  5 to 10 Yrs
# 9    0 to 1 Yr

# %% [raw]
# Q3: Scrape 100 reviews data from flipkart.com for iphone11 phone. You have to go the link:
# https://www.flipkart.com/apple-iphone-11-black-64-gb/product
# reviews/itm4e5041ba101fd?pid=MOBFWQ6BXGJCEYNY&lid=LSTMOBFWQ6BXGJCEYNYZXSHRJ&marketplace=F
#  LIPKART
#
#
# As shown in the above page you have to scrape the tick marked attributes. These are:
# 1. Rating
# 2. Review summary
# 3. Full review
# 4. You have to scrape this data for first 100reviews.

# %%
driver2=webdriver.Chrome()

# %%
driver2.get("https://www.flipkart.com/apple-iphone-11-black-64-gb/product-reviews/itm4e5041ba101fd?pid=MOBFWQ6BXGJCEYNY&lid=LSTMOBFWQ6BXGJCEYNYZXSHRJ&marketplace=FLIPKART")

# %%
star_ratings = []
review_texts = []
full_reviews = []

# %%
# Scrape 100 reviews in 10 pages

for page in range(11):  # 10 pages
    # Find all reviews on the current page
    reviews = driver2.find_elements(By.CLASS_NAME, 'z9E0IG')  # Adjusted class name
    
    for review in reviews:
        # Extract review text
        review_text = review.text.strip()
        
        # Append review text to list
        review_texts.append(review_text)
    
    # Check if we have collected 100 reviews
    if len(review_texts) >= 100:
        break
    
    # Click on the next button to go to the next page
    try:
        next_button = driver2.find_element(By.CLASS_NAME, "_9QVEpD")
        next_button.click()
        time.sleep(3)  # Introducing a sleep to wait for the next page to load
    except Exception as e:
        print(f"Error clicking next button: {str(e)}")
        break

# Print or further process the scraped review texts
for i, review_text in enumerate(review_texts[:100]):  # Only print the first 100 reviews
    print(f"Review {i+1}:")
    print(f"Review Text: {review_text}")
    print("=" * 50)
# Out:
# Review 1:
# Review Text: Worth every penny
# ...
# Review 2:
# Review Text: Best in the market!
# ...
# Review 3:
# Review Text: Terrific
# ...
# Review 4:
# Review Text: Wonderful
# ...
# Review 5:
# Review Text: Just wow!
# ...
# Review 6:
# Review Text: Perfect product!
# ...
# Review 7:
# Review Text: Classy product
# ...
# Review 8:
# Review Text: Must buy!
# ...
# Review 9:
# Review Text: Fabulous!
# ...
# Review 10:
# Review Text: Terrific purchase
# ...
# Review 11:
# Review Text: Fabulous!
# ...
# Review 12:
# Review Text: Perfect product!
# ...
# Review 13:
# Review Text: Super!
# ...
# Review 14:
# Review Text: Awesome
# ...
# Review 15:
# Review Text: Highly recommended
# ...
# Review 16:
# Review Text: Great product
# ...
# Review 17:
# Review Text: Brilliant
# ...
# Review 18:
# Review Text: Must buy!
# ...
# Review 19:
# Review Text: Excellent
# ...
# Review 20:
# Review Text: Best in the market!
# ...
# Review 21:
# Review Text: Worth every penny
# ...
# Review 22:
# Review Text: Best in the market!
# ...
# Review 23:
# Review Text: Terrific
# ...
# Review 24:
# Review Text: Wonderful
# ...
# Review 25:
# ...

# %%
# Scrape 100 ratings in 10 pages

for page in range(10):  # 10 pages
    # Find all ratings on the current page
    ratings = driver2.find_elements(By.CLASS_NAME, 'XQDdHH Ga3i8K')  # Adjusted class name
    
    for rating in ratings:
        # Extract review text
        rating_text = rating.text.strip()
        
        # Append review text to list
        star_ratings.append(rating_text)
    
    # Check if we have collected 100 reviews
    if len(star_ratings) >= 100:
        break
    
    # Click on the next button to go to the next page
    try:
        next_button = driver2.find_element(By.CLASS_NAME, "_9QVEpD")
        next_button.click()
        time.sleep(3)  # Introducing a sleep to wait for the next page to load
    except Exception as e:
        print(f"Error clicking next button: {str(e)}")
        break

# Print or further process the scraped review texts
for i, rating_text in enumerate(star_ratings[:100]):  
        print(f"Rating {i+1}:")
        print(f"Star ratings: {rating_text}")
        print("=" * 50)




# Scrape 100 reviews in 10 pages

for page in range(11):  # 10 pages
    # Find all reviews on the current page
    reviews = driver2.find_elements(By.CLASS_NAME, 'z9E0IG')  # Adjusted class name
    
    for review in reviews:
        # Extract review text
        review_text = review.text.strip()
        
        # Append review text to list
        review_texts.append(review_text)
    
    # Check if we have collected 100 reviews
    if len(review_texts) >= 100:
        break
    
    # Click on the next button to go to the next page
    try:
        next_button = driver2.find_element(By.CLASS_NAME, "_9QVEpD")
        next_button.click()
        time.sleep(3)  # Introducing a sleep to wait for the next page to load
    except Exception as e:
        print(f"Error clicking next button: {str(e)}")
        break

# Print or further process the scraped review texts
for i, review_text in enumerate(review_texts[:100]):  # Only print the first 100 reviews
    print(f"Review {i+1}:")
    print(f"Review Text: {review_text}")
    print("=" * 50)
# Out:
# Rating 1:
# Star ratings: 4.6
# ...
# Rating 2:
# Star ratings: 5
# ...
# Rating 3:
# Star ratings: 5
# ...
# Rating 4:
# Star ratings: 5
# ...
# Rating 5:
# Star ratings: 5
# ...
# Rating 6:
# Star ratings: 5
# ...
# Rating 7:
# Star ratings: 5
# ...
# Rating 8:
# Star ratings: 5
# ...
# Rating 9:
# Star ratings: 5
# ...
# Rating 10:
# Star ratings: 5
# ...
# Rating 11:
# Star ratings: 5
# ...
# Rating 12:
# Star ratings: 4.6
# ...
# Rating 13:
# Star ratings: 5
# ...
# Rating 14:
# Star ratings: 5
# ...
# Rating 15:
# Star ratings: 5
# ...
# Rating 16:
# Star ratings: 5
# ...
# Rating 17:
# Star ratings: 5
# ...
# Rating 18:
# Star ratings: 5
# ...
# Rating 19:
# Star ratings: 5
# ...
# Rating 20:
# Star ratings: 5
# ...
# Rating 21:
# Star ratings: 5
# ...
# Rating 22:
# Star ratings: 5
# ...
# Rating 23:
# Star ratings: 4.6
# ...
# Rating 24:
# Star ratings: 5
# ...
# Rating 25:
# Star ratings: 5
# ...
# Rating 26:
# Star ratings: 5
# ...
# Rating 27:
# Star ratings: 5
# ...
# Rating 28:
# Star ratings: 5
# ...
# Rating 29:
# Star ratings: 5
# ...
# Rating 30:
# Star ratings: 5
# ...
# Rating 31:
# Star ratings: 5
# ...
# Rating 32:
# Star ratings: 5
# ...

# %%
for page in range(11):  # 10 pages
    # Find all reviews on the current page
    fullreviews = driver2.find_elements(By.CLASS_NAME, 'z9E0IG')  # Adjusted class name
    
    for fullreview in fullreviews:
        # Extract review text
        fullreview_text = fullreview.text.strip()
        
        # Append review text to list
        full_reviews.append(fullreview_text)
    
    # Check if we have collected 100 reviews
    if len(full_reviews) >= 100:
        break
    
    # Click on the next button to go to the next page
    try:
        next_button = driver2.find_element(By.CLASS_NAME, "_9QVEpD")
        next_button.click()
        time.sleep(3)  # Introducing a sleep to wait for the next page to load
    except Exception as e:
        print(f"Error clicking next button: {str(e)}")
        break

# Print or further process the scraped review texts
for i, fullreview_text in enumerate(full_reviews[:100]):  # Only print the first 100 reviews
    print(f"Full Review {i+1}:")
    print(f" Full Review Text: {fullreview_text}")
    print("=" * 50)
# Out:
# Full Review 1:
#  Full Review Text: Fabulous!
# ...
# Full Review 2:
#  Full Review Text: Perfect product!
# ...
# Full Review 3:
#  Full Review Text: Super!
# ...
# Full Review 4:
#  Full Review Text: Awesome
# ...
# Full Review 5:
#  Full Review Text: Highly recommended
# ...
# Full Review 6:
#  Full Review Text: Great product
# ...
# Full Review 7:
#  Full Review Text: Brilliant
# ...
# Full Review 8:
#  Full Review Text: Must buy!
# ...
# Full Review 9:
#  Full Review Text: Excellent
# ...
# Full Review 10:
#  Full Review Text: Best in the market!
# ...
# Full Review 11:
#  Full Review Text: Worth every penny
# ...
# Full Review 12:
#  Full Review Text: Best in the market!
# ...
# Full Review 13:
#  Full Review Text: Terrific
# ...
# Full Review 14:
#  Full Review Text: Wonderful
# ...
# Full Review 15:
#  Full Review Text: Just wow!
# ...
# Full Review 16:
#  Full Review Text: Perfect product!
# ...
# Full Review 17:
#  Full Review Text: Classy product
# ...
# Full Review 18:
#  Full Review Text: Must buy!
# ...
# Full Review 19:
#  Full Review Text: Fabulous!
# ...
# Full Review 20:
# ...

# %% [raw]
# Q4: Scrape data for first 100 sneakers you find when you visit flipkart.com and search for “sneakers” in the search
# field.
# You have to scrape 3 attributes of each sneaker:
# 1. Brand
# 2. Product Description
# 3. Price
# As shown in the below image, you have to scrape the above attributes.

# %%
driver3=webdriver.Chrome()

# %%
driver3.get("https://www.flipkart.com/")

# %%
search_brand = driver3.find_element(By.XPATH, "//input[@type='text']")

# Use send_keys to type into the input field
search_brand.send_keys("sneakers")

# %%
search=driver3.find_element(By.CLASS_NAME,'_2iLD__')
search.click()
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 search=driver3.find_element(By.CLASS_NAME,'_2iLD__')
#       2 search.click()
#
# File D:\Anacodna 25.05.2024\Lib\site-packages\selenium\webdriver\remote\webdriver.py:748, in WebDriver.find_element(self, by, value)
#     745     by = By.CSS_SELECTOR
#     746     value = f'[name="{value}"]'
# --> 748 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File D:\Anacodna 25.05.2024\Lib\site-packages\selenium\webdriver\remote\webdriver.py:354, in WebDriver.execute(self, driver_command, params)
#     352 response = self.command_executor.execute(driver_command, params)
#     353 if response:
# --> 354     self.error_handler.check_response(response)
#     355     response["value"] = self._unwrap_value(response.get("value", None))
#     356     return response
#
# ...

# %%
brand_names=[]
prod_desc=[]
product_price=[]

# %%
# Loop through pages (up to 10 pages)
for page in range(10):  # This will loop through 10 pages (0 to 9)

    # Locate all brand elements on the current page
    brand_elements = driver3.find_elements(By.CLASS_NAME, 'syl9yP')

    # Extract brand names
    for brand_element in brand_elements:
        brand_name = brand_element.text.strip()
        brand_names.append(brand_name)

        # Check if we have collected 100 brand names
        if len(brand_names) >= 100:
            break
    
    # Check if we have collected 100 brand names
    if len(brand_names) >= 100:
        break
    
    # Click on the next button to go to the next page
    try:
        next_button = driver3.find_element(By.XPATH, '//a[@class="_9QVEpD"]')
        next_button.click()
        time.sleep(3) 
        page += 1
    except Exception as e:
        print(f"Error clicking next button: {str(e)}")
        break

# Print or further process the scraped brand names
for i, brand_name in enumerate(brand_names[:100]):
    print(f"Brand {i+1}: {brand_name}")
    print("=" * 50)
# Out:
# Brand 1: BRUTON
# ...
# Brand 2: BRUTON
# ...
# Brand 3: Deals4you
# ...
# Brand 4: aadi
# ...
# Brand 5: PUMA
# ...
# Brand 6: U.S. POLO ASSN.
# ...
# Brand 7: BRUTON
# ...
# Brand 8: BRUTON
# ...
# Brand 9: Zixer
# ...
# Brand 10: aadi
# ...
# Brand 11: BRUTON
# ...
# Brand 12: BRUTON
# ...
# Brand 13: ATOM
# ...
# Brand 14: aadi
# ...
# Brand 15: ATOM
# ...
# Brand 16: asian
# ...
# Brand 17: BRUTON
# ...
# Brand 18: aadi
# ...
# Brand 19: aadi
# ...
# Brand 20: RapidBox
# ...
# Brand 21: BRUTON
# ...
# Brand 22: BRUTON
# ...
# Brand 23: asian
# ...
# Brand 24: aadi
# ...
# Brand 25: PUMA
# ...
# Brand 26: URBANBOX
# ...
# Brand 27: BRUTON
# ...
# Brand 28: JUMPLITE
# ...
# Brand 29: asian
# ...
# Brand 30: Roadster
# ...
# Brand 31: aadi
# ...
# Brand 32: New Balance
# ...
# Brand 33: asian
# ...
# Brand 34: VENDOZ
# ...
# Brand 35: Red Tape
# ...
# Brand 36: Kzaara
# ...
# Brand 37: Zixer
# ...
# Brand 38: PUMA
# ...
# Brand 39: aadi
# ...
# Brand 40: Red Tape
# ...
# Brand 41: RUN SEVEN
# ...
# Brand 42: aadi
# ...
# Brand 43: VENDOZ
# ...
# Brand 44: Sparx
# ...
# Brand 45: PUMA
# ...
# Brand 46: U.S. POLO ASSN.
# ...
# Brand 47: Aqualite
# ...
# Brand 48: aadi
# ...
# Brand 49: CAMPUS
# ...
# Brand 50: Kook N Keech
# ...
# Brand 51: Aqualite
# ...
# Brand 52: RUN SEVEN
# ...

# %%
print(len(brand_names))
# Out:
# 100

# %%
# Loop through pages (up to 10 pages)
for page in range(10):  # This will loop through 10 pages (0 to 9)

    # Locate all brand elements on the current page
    prod_elements = driver3.find_elements(By.CLASS_NAME, 'WKTcLC')

    # Extract brand names
    for prod_element in prod_elements:
        prod = prod_element.text.strip()
        prod_desc.append(prod)

        # Check if we have collected 100 brand names
        if len(prod_desc) >= 100:
            break
     
    # Click on the next button to go to the next page
    try:
        next_button = driver3.find_element(By.CLASS_NAME, 'TEAQU1')
        next_button.click()
        time.sleep(3)  # Introducing a sleep to wait for the next page to load
        page += 1
    except Exception as e:
        print(f"Error clicking next button: {str(e)}")
        break

# Print or further process the scraped brand names
for i, prod in enumerate(prod_desc[:100]):
    print(f"Prod descrption {i+1}: {prod}")
    print("=" * 50)
# Out:
# Error clicking next button: Message: element not interactable
#   (Session info: chrome=126.0.6478.127)
# Stacktrace:
# 	GetHandleVerifier [0x00007FF60925EEA2+31554]
# 	(No symbol) [0x00007FF6091D7ED9]
# 	(No symbol) [0x00007FF609098559]
# 	(No symbol) [0x00007FF6090E97C2]
# 	(No symbol) [0x00007FF6090DC151]
# 	(No symbol) [0x00007FF60910D02A]
# 	(No symbol) [0x00007FF6090DBA76]
# 	(No symbol) [0x00007FF60910D240]
# 	(No symbol) [0x00007FF60912C977]
# 	(No symbol) [0x00007FF60910CDD3]
# 	(No symbol) [0x00007FF6090DA33B]
# 	(No symbol) [0x00007FF6090DAED1]
# 	GetHandleVerifier [0x00007FF609568B1D+3217341]
# 	GetHandleVerifier [0x00007FF6095B5AE3+3532675]
# 	GetHandleVerifier [0x00007FF6095AB0E0+3489152]
# 	GetHandleVerifier [0x00007FF60930E776+750614]
# 	(No symbol) [0x00007FF6091E375F]
# 	(No symbol) [0x00007FF6091DEB14]
# 	(No symbol) [0x00007FF6091DECA2]
# 	(No symbol) [0x00007FF6091CE16F]
# 	BaseThreadInitThunk [0x00007FFC66BA55A0+16]
# 	RtlUserThreadStart [0x00007FFC679E485B+43]
# ...

# %%
# Loop through pages (up to 10 pages)
for page in range(10):  # This will loop through 10 pages (0 to 9)

    # Locate all brand elements on the current page
    price_elements = driver3.find_elements(By.XPATH, '//div[@class="Nx9bqj"]')

    # Extract brand names
    for pricelement in price_elements:
        price = price_element.text.strip()
        product_price.append(price)

        # Check if we have collected 100 brand names
        if len(product_price) >= 100:
            break
     
    # Click on the next button to go to the next page
    try:
        next_button = driver3.find_element(By.CLASS_NAME, 'TEAQU1')
        next_button.click()
        time.sleep(5)  # Introducing a sleep to wait for the next page to load
        page += 1
    except Exception as e:
        print(f"Error clicking next button: {str(e)}")
        break

# Print or further process the scraped brand names
for i, pri in enumerate(product_price[:100]):
    print(f"Price descrption {i+1}: {pri}")
    print("=" * 50)

# %% [raw]
# https://www.selenium.dev/selenium/docs/api/py/common/selenium.common.exceptions.html#module-selenium.common.exceptions
# https://selenium-python.readthedocs.io/api.html

# %% [raw]
# Q5: Go to webpage https://www.amazon.in/ Enter “Laptop” in the search field and then click the search icon. Then set CPU
# Type filter to “Intel Core i7” as shown in the below image:
# Aftersetting the filters scrape first 10 laptops data. You have to scrape 3 attributes for each laptop:
# 1. Title
# 2. Ratings
# 3. Price

# %%
driver4=webdriver.Chrome()

# %%
driver4.get("https://www.amazon.in/")

# %%
search_box = driver4.find_element(By.ID, "twotabsearchtextbox")
search_box.send_keys("Laptop")

# %%
search_button = driver4.find_element(By.XPATH, "//input[@value='Go']")
search_button.click()

# %%
processor=driver4.find_element(By.XPATH, "//span[text()='Intel Core i7']/preceding-sibling::div")
processor.click()

# %%
title_tags = driver4.find_elements(By.XPATH, '//h2[@class="a-size-mini a-spacing-none a-color-base s-line-clamp-2"]')

item_titles = []

for i, tag in enumerate(title_tags):
    if i < 10:  # Limit to first 10 job titles
        item_title = tag.text
        item_titles.append(item_title)
    else:
        break 
for title in item_titles:
    print(title)
# Out:
# MSI Modern 14, Intel 12th Gen. i7-1255U, 36CM FHD 60Hz Laptop (16GB/512GB NVMe SSD/Windows 11 Home/Intel Iris Xe Graphics/Classic Black/1.4Kg), C12M-459IN
# HP Laptop 15s, 12th Gen Intel Core i7-1255U, 15.6-inch (39.6 cm), FHD, 16GB DDR4, 512GB SSD, Intel Iris Xe graphics, Backlit KB, Thin & light (Win 11, MSO 2021, Silver, 1.69 kg), fq5190TU
# Lenovo IdeaPad 3 Intel Core i7 12th Gen 1255U - (16 GB/512 GB SSD/Windows 11 Home) 15IAU7 Laptop 82RK011GIN (39.62 cm, Arctic Grey, 1.63 Kg, with MS Office)
# ASUS Vivobook 15, Intel Core i7-12650H 12th Gen, 15.6" (39.62 cm) FHD, Thin and Light Laptop (16GB/512GB/Win11/Office 2021/Blue/1.7 kg), X1502ZA-EJ741WS
# Lenovo IdeaPad Slim 5 Intel Core i7 13700H 16" (40.6cm) 2.5K IPS 350Nits Laptop (16GB/1TB SSD/Win 11/Office 2021/Backlit KB/FHD 1080p +IR Camera/Alexa/3 month Game Pass/Cloud Grey/1.9Kg), 82XF0078IN
# ...

# %%
print(len(item_titles))
# Out:
# 10

# %%
rating_tags = driver4.find_elements(By.XPATH, '//div[@class="a-row a-size-small"]')

rating_titles = []

for i, tag in enumerate(rating_tags):
    if i < 10:  # Limit to first 10 job titles
        rating = tag.text
        rating_titles.append(rating)
    else:
        break 
for rating in rating_titles:
    print(rating)
# Out:
# 131
# 63
# 337
# 270
# 22
# 122
# 686
# 106
# 34
# 39

# %%
price_tags = driver4.find_elements(By.XPATH, '//span[@class="a-price-whole"]')
#price_tags = driver4.find_elements(By.CLASS_NAME, 'a-price-whole')
price_titles = []

for i, tag in enumerate(price_tags):
    if i < 10:  # Limit to first 10 job titles
        price = tag.text
        price_titles.append(price)
    else:
        break 
for price in price_titles:
    print(price)
# Out:
# 47,990
# 64,990
# 47,990
# 65,490
# 62,009
# 64,990
# 84,190
# 78,850
# 80,490
# 66,990

# %%
import pandas as pd
df1=pd.DataFrame({"Latop Title":item_titles,"Ratings":rating_titles,"Cost":price_titles})
df1
# Out:
#                                          Latop Title Ratings    Cost
# 0  MSI Modern 14, Intel 12th Gen. i7-1255U, 36CM ...     131  47,990
# 1  HP Laptop 15s, 12th Gen Intel Core i7-1255U, 1...      63  64,990
# 2  Lenovo IdeaPad 3 Intel Core i7 12th Gen 1255U ...     337  47,990
# 3  ASUS Vivobook 15, Intel Core i7-12650H 12th Ge...     270  65,490
# 4  Lenovo IdeaPad Slim 5 Intel Core i7 13700H 16"...      22  62,009
# 5  HP Pavilion 14 12th Gen Intel Core i7 16GB SDR...     122  64,990
# 6  Dell Latitude 7480 14in FHD Laptop PC - Intel ...     686  84,190
# 7  Dell [Smartchoice Inspiron 5430 Thin & Light L...     106  78,850
# 8  HP Pavilion 14, 11th Gen Intel Core i7-1195G7,...      34  80,490
# 9  HP Pavilion 15, 13th Gen Intel Core i7-1360P, ...      39  66,990

# %%
Q6: Write a python program to scrape data for Top 1000 Quotes of All Time. 
The above task will be done in following steps: 
1. First get the webpagehttps://www.azquotes.com/ 
2. Click on Top Quote 
3. Than scrap a) Quote b) Author c) Type Of Quotes

# %%
driver5=webdriver.Chrome()

# %%
driver5.get("https://www.azquotes.com/")

# %%
topquote=driver5.find_element(By.XPATH, "//a[contains(text(), 'Top Quotes')]")
topquote.click()

# %%
 time.sleep(3)  # Let the page load
    
quotes_data = []
page_count = 0

while True:
    for quote_elem in quote_elements:
            # Extract Quote
            quote_text = quote_elem.find_element(By.XPATH, '//a[@class="title"]').text.strip()
            
            # Extract Author
            author = quote_elem.find_element(By.XPATH, '//div[@class="author"]').text.strip()
            
            # Extract Type of Quote
            type_of_quote = quote_elem.find_element(By.XPATH, '//div[@class="tags"]').text.strip()
            
            # Store the data in a dictionary
            quote_data = {
                'quote': quote_text,
                'author': author,
                'type': type_of_quote
            }
            
            quotes_data.append(quote_data)
        
    page_count += 1
    print(f"Scraped quotes from page {page_count}")
        
    # Check if we have scraped 1000 quotes
    if len(quotes_data) >= 1000:
        break
        next_page_btn = driver5.find_element(By.XPATH, '/html/body/div[1]/div[2]/div/div/div/div[1]/div/div[3]/li[12]')
        if not next_page_btn.is_enabled():
            break
        next_page_btn.click()
        time.sleep(3)  # Let the next page load

    
return quotes_data[:1000]

# Print the total number of quotes scraped
print(f"Total quotes scraped: {len(top_quotes)}")
# Out:
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# Cell In[57], line 9
#       6 while True:
#       7    for quote_elem in quote_elements:
#       8            # Extract Quote
# ----> 9            quote_text = quote_elem.find_element(By.XPATH, '//a[@class="title"]').text.strip()
#      11            # Extract Author
#      12            author = quote_elem.find_element(By.XPATH, '//div[@class="author"]').text.strip()
#
# File D:\Anacodna 25.05.2024\Lib\site-packages\selenium\webdriver\remote\webelement.py:417, in WebElement.find_element(self, by, value)
#     414     by = By.CSS_SELECTOR
#     415     value = f'[name="{value}"]'
# --> 417 return self._execute(Command.FIND_CHILD_ELEMENT, {"using": by, "value": value})["value"]
#
# File D:\Anacodna 25.05.2024\Lib\site-packages\selenium\webdriver\remote\webelement.py:395, in WebElement._execute(self, command, params)
# ...

# %%
print(len(rating_titles))
# Out:
# 0
